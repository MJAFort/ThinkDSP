# %% [markdown]
# # Madeleine Fort: PS02

# %%
from __future__ import print_function, division

import thinkdsp
import thinkdspHanning
import thinkplot
import numpy
from numpy import bartlett

# %precision 3
# %matplotlib inline

# %% [markdown]
# # 1.

# %%
signal = thinkdsp.SinSignal(freq=440)

# %%
duration = signal.period * 30.5
wave = signal.make_wave(duration)

# %%
spectrum = wave.make_spectrum()

# %%
spectrum.plot(high=50)
thinkplot.config(xlabel='frequency (Hz)', ylabel='amplitude', legend=False)

# %% [markdown]
# Here is the plot of the sine signal without any windowing.

# %%
wave.hamming()
spectrum = wave.make_spectrum()
spectrum.plot(high=50)
thinkplot.config(xlabel='frequency (Hz)', ylabel='amplitude', legend=False)

# %% [markdown]
# Here we have the spectrum after the hamming window was applied.

# %%
signal = thinkdspHanning.SinSignal(freq=440)

# %%
duration = signal.period * 30.5
wave = signal.make_wave(duration)

# %%
l = wave.hanning()
spectrum = l.make_spectrum()
spectrum.plot(high=50)
thinkplot.config(xlabel='frequency (Hz)', ylabel='amplitude', legend=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f7d043b381ab> in <module>()
#       1 l = wave.hanning()
# ----> 2 spectrum = l.make_spectrum()
#       3 spectrum.plot(high=50)
#       4 thinkplot.config(xlabel='frequency (Hz)', ylabel='amplitude', legend=False)
#
# AttributeError: 'NoneType' object has no attribute 'make_spectrum'

# %% [markdown]
# A hanning window applied to the same signal.

# %% [markdown]
# # 2.

# %% [markdown]
# # 4.

# %% [markdown]
# The following recording is from freesound.org and is a recording of someone saying the phonetic vowel sounds.  Ipython notebook thought it would be hilarious to play everything at half speed.

# %%
vowels = thinkdsp.read_wave('vowels.wav')
vowels.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrogram = vowels.make_spectrogram(seg_length=1024)
spectrogram.plot(high=64)
thinkplot.config(xlabel='time(s)', ylabel='frequency (Hz)', legend=False)

# %% [markdown]
# This is the spectrogram of the entire wave.  The recording goes: aeiou.

# %%
start = 1.5
duration = 1.25
segmenta = vowels.segment(start,duration)
spectrogram = segmenta.make_spectrogram(seg_length=1024)
spectrogram.plot(high=64)
thinkplot.config(xlabel='time(s)', ylabel='frequency (Hz)', legend=False)

# %% [markdown]
# Above is the spectrogram of the vowel a.

# %%
start = 6.8
duration = 1
segmenti = vowels.segment(start,duration)
spectrogram = segmenti.make_spectrogram(seg_length=1024)
spectrogram.plot(high=64)
thinkplot.config(xlabel='time(s)', ylabel='frequency (Hz)', legend=False)

# %% [markdown]
# We contrast the spectrogram of the vowel a with the spectrogram for the vowel i and see that i has considerably lower frequency over time.

# %% [markdown]
# # 5.

# %% [markdown]
# The first wave is a struck tibetan singing bowl.

# %%
start = 0
duration = 5
chime = thinkdsp.read_wave('chime.wav')
chimeSegment = chime.segment(start, duration)
chimeSegment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
chimeSpectrum = chimeSegment.make_spectrum()
chimeSpectrum.plot()

# %%
chimeSpectrum.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power density',
                 xscale='log',
                 yscale='log',
                 legend=False)

# %%
chimeSpectrum.estimate_slope()
# Out:
# (-2.169, 39.601, -0.649, 0.000, 0.008)

# %% [markdown]
# The power spectrum reveals that the slope is approximately -1.  This indicates that the waveform is more closely related to pink noise than to white or brown.

# %% [markdown]
# Our second wave is a tibetan singing bowl that is played by scraping across the top of the bowl.

# %%
start = 16
duration = .5
crystal = thinkdsp.read_wave('crystal.wav')
crystalSegment = crystal.segment(start, duration)
crystalSegment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
crystalSpectrum = crystalSegment.make_spectrum()
crystalSpectrum.plot()

# %%
crystalSpectrum.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power density',
                 xscale='log',
                 yscale='log',
                 legend=False)

# %%
crystalSpectrum.estimate_slope()
# Out:
# (-0.896, 38.223, -0.530, 0.000, 0.014)

# %% [markdown]
# This wave is not white, pink, or red noise.  Instead it seems to be black noise with a  beta value >3.

# %% [markdown]
# The last wave is, in fact, waves from the north sea.

# %%
start = 0
duration = 5
ocean = thinkdsp.read_wave('Ocean.wav')
oceanSegment = ocean.segment(start, duration)
oceanSegment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
oceanSpectrum = oceanSegment.make_spectrum()
oceanSpectrum.plot()

# %%
oceanSpectrum.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power density',
                 xscale='log',
                 yscale='log',
                 legend=False)

# %%
oceanSpectrum.estimate_slope()
# Out:
# (-1.998, 54.679, -0.759, 0.000, 0.005)

# %% [markdown]
# From this data, it appears that the ocean waves are pink noise, but are closer to white than red.
